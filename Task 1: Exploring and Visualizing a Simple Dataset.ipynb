# %% [markdown]
# # **✅ Step 1: Required Libraries And  Load Dataset**

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
# Load your dataset (update filename accordingly)
file_path = "/kaggle/input/iris-dataset/iris.csv"
df = pd.read_csv(file_path)

# Display first few rows
df.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width species
# 0           5.1          3.5           1.4          0.2  setosa
# 1           4.9          3.0           1.4          0.2  setosa
# 2           4.7          3.2           1.3          0.2  setosa
# 3           4.6          3.1           1.5          0.2  setosa
# 4           5.0          3.6           1.4          0.2  setosa

# %% [markdown]
# # **✅ Step 2: Inspect the Dataset**

# %%
# Shape of the dataset
print("Shape:", df.shape)

# Column names
print("Columns:", df.columns.tolist())

# First few rows
print(df.head())
# Out:
# Shape: (150, 5)
# Columns: ['sepal_length', 'sepal_width', 'petal_length', 'petal_width', 'species']
#    sepal_length  sepal_width  petal_length  petal_width species
# 0           5.1          3.5           1.4          0.2  setosa
# 1           4.9          3.0           1.4          0.2  setosa
# 2           4.7          3.2           1.3          0.2  setosa
# 3           4.6          3.1           1.5          0.2  setosa
# 4           5.0          3.6           1.4          0.2  setosa

# %% [markdown]
# # **✅ Step 3: Summary Statistics**

# %%
# Info summary
print(df.info())

# Descriptive statistics
print(df.describe())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 150 entries, 0 to 149
# Data columns (total 5 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   sepal_length  150 non-null    float64
#  1   sepal_width   150 non-null    float64
#  2   petal_length  150 non-null    float64
#  3   petal_width   150 non-null    float64
#  4   species       150 non-null    object
# dtypes: float64(4), object(1)
# memory usage: 6.0+ KB
# None
#        sepal_length  sepal_width  petal_length  petal_width
# count    150.000000   150.000000    150.000000   150.000000
# mean       5.843333     3.054000      3.758667     1.198667
# std        0.828066     0.433594      1.764420     0.763161
# min        4.300000     2.000000      1.000000     0.100000
# 25%        5.100000     2.800000      1.600000     0.300000
# 50%        5.800000     3.000000      4.350000     1.300000
# 75%        6.400000     3.300000      5.100000     1.800000
# ...

# %% [markdown]
# **Show Columns**

# %%
print(df.columns)
# Out:
# Index(['sepal_length', 'sepal_width', 'petal_length', 'petal_width',
#        'species'],
#       dtype='object')

# %% [markdown]
# # **✅ Step 4: Data Visualization**

# %% [markdown]
# **🔹 Scatter Plot: SepalLength vs SepalWidth**

# %%
sns.scatterplot(data=df, x='sepal_length', y='sepal_width', hue='species')
plt.title('Sepal Length vs Sepal Width')
plt.show()

# %% [markdown]
# **🔹 Histograms: Distribution of All Features**

# %%
df.hist(figsize=(10, 8), bins=15)
plt.suptitle('Feature Distributions')
plt.tight_layout()
plt.show()

# %% [markdown]
# **🔹 Box Plots: Identify Outliers**

# %%
plt.figure(figsize=(12, 8))
for i, column in enumerate(df.columns[:-1], 1):  # Skip 'species'
    plt.subplot(2, 2, i)
    sns.boxplot(data=df, x='species', y=column)
    plt.title(f'Boxplot of {column}')
plt.tight_layout()
plt.show()

# %% [markdown]
# # **Other Working**
#
# # **✅ Step 5 Feature Correlation Heatmap**

# %%
from sklearn.preprocessing import LabelEncoder
le = LabelEncoder()
df['species'] = le.fit_transform(df['species'])
print(df['species'].value_counts())
# Out:
# species
# 0    50
# 1    50
# 2    50
# Name: count, dtype: int64

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
# Load the Iris dataset
from sklearn.datasets import load_iris
iris = load_iris()
df = pd.DataFrame(data=iris.data, columns=iris.feature_names)
# Create the correlation matrix
corr_matrix = df.corr()
# Plot the heatmap
plt.figure(figsize=(8,6))
sns.heatmap(corr_matrix, annot=True, cmap='Blues', linewidths=0.5)
plt.title("Feature Correlation Heatmap - Iris Dataset")
plt.show()

# %% [markdown]
# # **🌸 Project Title: Exploring and Visualizing the Iris Dataset**
#
#
#
# # **🎯Objective**
#
# The primary goal of this project is to perform exploratory data analysis (EDA) on the classic Iris dataset using Python libraries such as pandas, seaborn, and matplotlib. Through this task, we aim to:
#
# Load and inspect the dataset structure
#
# Generate descriptive statistics
#
# Visualize the relationships and distributions among features
#
# Detect any outliers or patterns
#
# Understand how different iris species vary in terms of measurements
#
# # **📂 Dataset Overview**
#
# Name: Iris Flower Dataset
#
# Source: Built-in dataset in Seaborn (also available as CSV)
#
# # **Attributes:**
#
# sepal_length (cm)
#
# sepal_width (cm)
#
# petal_length (cm)
#
# petal_width (cm)
#
# species (categorical target: setosa, versicolor, virginica)
#
# Total Records: 150
#
# This dataset is widely used for classification tasks and EDA practice due to its clean and well-structured nature.
#
# # **🛠️ Steps and Methodology**
# **🔹 1. Data Loading**
#
# The dataset was loaded using the seaborn.load_dataset() method or via CSV using pandas.read_csv().
#
# **🔹 2. Basic Data Inspection**
#
# .shape: Confirmed 150 rows × 5 columns
#
# .columns: Identified feature names
#
# .head(): Previewed the first 5 rows
#
# **🔹 3. Descriptive Statistics**
#
# .info() showed that all features are numerical except the categorical species
#
# .describe() provided summary statistics like mean, standard deviation, min, and quartiles
#
# # **🔹 4. Data Visualization**
#
# **📊 a. Scatter Plot (Sepal)**
#
# Compared sepal_length vs sepal_width with color-coded species
#
# Helped observe the natural clustering and spread of different iris species
#
# **📉 b. Histograms**
#
# Displayed the distribution of all numerical features
#
# Revealed that petal lengths and widths are more distinctive across species than sepals
#
# **📦 c. Box Plots**
#
# Plotted each feature grouped by species
#
# Identified outliers and inter-species differences in feature ranges
#
# Observed that setosa has distinctly smaller petal dimensions compared to other species
#
# # **🔍 Insights Gained**
#
# Petal features are more discriminative than sepal features for classifying species.
#
# Setosa is easily separable from Versicolor and Virginica.
#
# Versicolor and Virginica show some overlapping characteristics in sepal dimensions.
#
# Few mild outliers exist, but the dataset is relatively clean and balanced.
#
# # **🧠 Skills Practiced**
# ✅ Data loading and cleaning with pandas
#
# ✅ Statistical exploration using .info() and .describe()
#
# ✅ Plotting with matplotlib and seaborn
#
# ✅ Understanding feature relationships and distributions
#
# ✅ Identifying patterns for future machine learning applications
#
# #**✅ Conclusion**
#
# This project serves as a foundational exercise in data science by offering hands-on experience in data loading, inspection, and visualization. The Iris dataset is ideal for beginner-to-intermediate learners to understand:
#
# How to explore datasets systematically
#
# How to interpret basic statistical summaries
#
# How to visualize data to uncover relationships and trends
#
# The insights gained here lay the groundwork for building machine learning models, such as classification using logistic regression or decision trees in future tasks.
